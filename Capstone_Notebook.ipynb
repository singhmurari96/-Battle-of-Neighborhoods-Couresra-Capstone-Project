# %% [markdown]
# # Coursera Project Capstone- The Battle of Neighborhoods

# %% [markdown]
# ### Introduction
#
# Canada is a one of the most popular destination of Indian Engineering Students for advance studies and also for doing Internships like Mitacs etc. When new students go there, they usually miss the Indian foods badly, because of unique taste of native foods.
# <p>
# This Project is aimed to help them in finding <strong>the best Indian restaurants in Toronto, the provincial capital of Ontario, Canada</strong>. </p>
#
# I chose Toronto, because, the highest concentrations of Indo-Canadians are found in the provinces of Ontario and British Columbia, followed by growing communities in Alberta and Quebec as well, with the majority of them being foreign-born.

# %% [markdown]
# ### About Data
#
#
# For the Toronto neighborhood data, a Wikipedia page: <a href = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'>wiki_page</a> exists that has all the information we need to explore and cluster the neighborhoods in Toronto. I will have to scrape the Wikipedia page and wrangle the data, clean it, and then read it into a pandas dataframe so that it is in a structured format.

# %% [markdown]
# ### Approach
#
# I will collect the Toronto city data from above <a href = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'>link</a> and using <strong>FourSquare API</strong>, I will find all venues for each neighborhood. Then, filtering out all the venues that have Indian restaurants. I will analyse ratings, tips and count for Indian restaurants. I will sort that data and visualize the ranking of neighborhoods using <strong>folium library</strong> of Python.

# %% [markdown]
# ### Problem Statement :
#
# <strong>Which is/are the best place/s to stay in the Toronto city if I prefer Indian foods ?</strong>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup
#!pip install geocoder #uncomment if the module isn't installed
import os
#!pip install folium #uncomment if the module isn't installed
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Download, scrape and wrangle the data

# %%
# download data and parse it:
r = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(r.text, 'html.parser')
table=soup.find('table', attrs={'class':'wikitable sortable'})

#get headers:
headers=table.findAll('th')
for i, head in enumerate(headers): headers[i]=str(headers[i]).replace("<th>","").replace("</th>","").replace("\n","")

#Find all items and skip first one:
rows=table.findAll('tr')
rows=rows[1:len(rows)]

# skip all meta symbols and line feeds between rows:
for i, row in enumerate(rows): rows[i] = str(rows[i]).replace("\n</td></tr>","").replace("<tr>\n<td>","")

# make dataframe, expand rows and drop the old one:
df=pd.DataFrame(rows)
df[headers] = df[0].str.split("</td>\n<td>", n = 2, expand = True) 
df.drop(columns=[0],inplace=True)

# skip not assigned boroughs:
df = df.drop(df[(df.Borough == "Not assigned")].index)
# give "Not assigned" Neighborhoods same name as Borough:
df.Neighborhood.replace("Not assigned", df.Borough, inplace=True)

# copy Borough value to Neighborhood if NaN:
df.Neighborhood.fillna(df.Borough, inplace=True)
# drop duplicate rows:
df=df.drop_duplicates()

# extract titles from columns
df.update(
    df.Neighborhood.loc[
        lambda x: x.str.contains('title')
    ].str.extract('title=\"([^\"]*)',expand=False))

df.update(
    df.Borough.loc[
        lambda x: x.str.contains('title')
    ].str.extract('title=\"([^\"]*)',expand=False))

# delete Toronto annotation from Neighbourhood:
df.update(
    df.Neighborhood.loc[
        lambda x: x.str.contains('Toronto')
    ].str.replace(", Toronto",""))
df.update(
    df.Neighborhood.loc[
        lambda x: x.str.contains('Toronto')
    ].str.replace("\(Toronto\)",""))

# combine multiple neighborhoods with the same post code
df2 = pd.DataFrame({'Postcode':df.Postcode.unique()})
df2['Borough']=pd.DataFrame(list(set(df['Borough'].loc[df['Postcode'] == x['Postcode']])) for i, x in df2.iterrows())
df2['Neighborhood']=pd.Series(list(set(df['Neighborhood'].loc[df['Postcode'] == x['Postcode']])) for i, x in df2.iterrows())
df2['Neighborhood']=df2['Neighborhood'].apply(lambda x: ', '.join(x))
df2.dtypes

df2.head()
# Out:
#   Postcode           Borough                      Neighborhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto                       Regent Park
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A  Downtown Toronto                     Queen's Park

# %% [markdown]
# <strong>I will add Longitude and Latitude values for each neighborhood using <a href = 'http://cocl.us/Geospatial_data'>this data</a>.</strong>

# %%
#add Geo-spatial data
dfll= pd.read_csv("http://cocl.us/Geospatial_data")
dfll.rename(columns={'Postal Code':'Postcode'}, inplace=True)
dfll.set_index("Postcode")
df2.set_index("Postcode")
toronto_data=pd.merge(df2, dfll)
toronto_data.head()
# Out:
#   Postcode           Borough                      Neighborhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto                       Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A  Downtown Toronto                     Queen's Park   43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
# The "Post code" column is not needed
toronto_data = toronto_data.iloc[:, 1:]
toronto_data
# Out:
#                     Borough  \
# 0                North York
# 1                North York
# 2          Downtown Toronto
# 3                North York
# 4          Downtown Toronto
# 5    Queen's Park (Toronto)
# 6      Scarborough, Toronto
# 7                North York
# 8                 East York
# 9          Downtown Toronto
# 10               North York
# 11                Etobicoke
# 12     Scarborough, Toronto
# 13               North York
# 14                East York
# 15         Downtown Toronto
# 16                     York
# 17                Etobicoke
# 18     Scarborough, Toronto
# 19             East Toronto
# 20         Downtown Toronto
# 21                     York
# 22     Scarborough, Toronto
# 23                East York
# 24         Downtown Toronto
# 25         Downtown Toronto
# 26     Scarborough, Toronto
# 27               North York
# 28               North York
# 29                East York
# 30         Downtown Toronto
# 31             West Toronto
# 32     Scarborough, Toronto
# 33               North York
# 34               North York
# 35                East York
# 36         Downtown Toronto
# 37             West Toronto
# 38     Scarborough, Toronto
# 39               North York
# 40               North York
# 41             East Toronto
# 42         Downtown Toronto
# 43             West Toronto
# 44     Scarborough, Toronto
# 45               North York
# 46               North York
# 47             East Toronto
# 48         Downtown Toronto
# 49               North York
# 50               North York
# 51     Scarborough, Toronto
# 52               North York
# 53               North York
# 54             East Toronto
# 55               North York
# 56            York, Toronto
# 57               North York
# 58     Scarborough, Toronto
# 59               North York
# 60               North York
# 61          Central Toronto
# 62          Central Toronto
# 63            York, Toronto
# 64            York, Toronto
# 65     Scarborough, Toronto
# 66               North York
# 67          Central Toronto
# 68          Central Toronto
# 69             West Toronto
# 70                Etobicoke
# 71     Scarborough, Toronto
# 72               North York
# 73          Central Toronto
# 74          Central Toronto
# 75             West Toronto
# 76              Mississauga
# 77                Etobicoke
# 78     Scarborough, Toronto
# 79          Central Toronto
# 80         Downtown Toronto
# 81             West Toronto
bedford Park, Lawrence Manor East  43.733283 -79.419750
# 56      Keelesdale, Mount Dennis, Del Ray, Silverthorn  43.691116 -79.476013
# 57                                    Emery, Humberlea  43.724766 -79.532242
# 58                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 59                                    Willowdale South  43.770120 -79.408493
# 60                                 Downsview Northwest  43.761631 -79.520999
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 63                       The Junction North, Runnymede  43.673185 -79.487262
# 64                                              Weston  43.706876 -79.518188
# 65   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 66                                     York Mills West  43.752758 -79.400049
# 67                                    Davisville North  43.712751 -79.390197
# 68                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 69                       The Junction South, High Park  43.661608 -79.464763
# 70                                           Westmount  43.696319 -79.532242
# 71                                   Wexford, Maryvale  43.750072 -79.295849
# 72                                     Willowdale West  43.782736 -79.442259
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, Yorkville, North Midtown  43.672710 -79.405678
# 75                              Roncesvalles, Parkdale  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Richview Gardens, Martin Grove Gardens, St. Ph...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82   Sullivan, Tam O'Shanter – Sullivan, Clarks Cor...  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84          Grange Park , Chinatown, Kensington Market  43.653206 -79.400049
# 85   L'Amoreaux East, Steeles East, Milliken, Ontar...  43.815252 -79.284577
# 86   Summerhill West, Forest Hill SE, South Hill, D...  43.686412 -79.400049
# 87   Railway Lands, Harbourfront West, CN Tower, So...  43.628947 -79.394420
# 88        Humber Bay Shores, New Toronto, Mimico South  43.605647 -79.501321
# 89   Albion Gardens, Thistletown, Humbergate, Mount...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Long Branch, Alderwood  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              Underground city, First Canadian Place  43.648429 -79.382280
# 98       Montgomery Road, Old Mill North, The Kingsway  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  King's Mill Park, Kingsway Park South East, Su...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico, The Queenswa...  43.628841 -79.520999

# %% [markdown]
#  ### Lets Visualize the location data :

# %%
# How many  neighborhood are there in Toronto City?
print("Total number of Neighborhood is {}".format(toronto_data.shape[0]))
# Out:
# Total number of Neighborhood is 103

# %% [markdown]
# <strong>Lets see which Borough has the most number of Neighborhood?</strong>

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in Toronto')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=15)
#giving a bar plot
toronto_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print("Maximum number of Neighborhoods in a single borough is {}".format(max(toronto_data.groupby('Borough')['Neighborhood'].count())))
# Out:
# Maximum number of Neighborhoods in a single borough is 24

# %% [markdown]
# ### Define Foursquare Credentials and Version
# All the below credentials are taken from <a href = 'https://foursquare.com/'>fourSquare</a>

# %%
CLIENT_ID = 'EU203ECLXW5SW1V211ZES5RUDZNHLCQ3HKADMVJHBUFZ4YLY' # your Foursquare ID
CLIENT_SECRET = 'IYS0KQOFTEKGJCJZHMKN32GMR1BNBTMS0F0RDDEMDHJNAWGA' # your Foursquare Secret
VERSION = '20200101'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EU203ECLXW5SW1V211ZES5RUDZNHLCQ3HKADMVJHBUFZ4YLY
# CLIENT_SECRET:IYS0KQOFTEKGJCJZHMKN32GMR1BNBTMS0F0RDDEMDHJNAWGA

# %% [markdown]
# <strong> Define all the functions intract with FourSquare API and get top 50 venues within a radius of 2000 metres for a given latitude and longitude. Below function will return us the venue id , venue name and category.</strong>

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=2000
    LIMIT=50
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# <strong>Function to get venue details like like count , rating , tip counts for a given venue id. This will be used for ranking.</strong>

# %%
def get_venue_details(venue_id):
        
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ### Let's collect the Indian Restaurants for each of the Neighbourhood

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name']
indirest_toronto = pd.DataFrame(columns=column_names)
count=1
for row in toronto_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    indian_resturants = venues[venues['Category']=='Indian Restaurant']   
    print('(',count,'/',len(toronto_data),')','Indian Resturants in '+Neighborhood+', '+Borough+':'+str(len(indian_resturants)))
    for resturant_detail in indian_resturants.values.tolist():
        id, name , category = resturant_detail
        indirest_toronto = indirest_toronto.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 103 ) Indian Resturants in Parkwoods, North York:0
# ( 2 / 103 ) Indian Resturants in Victoria Village, North York:1
# ( 3 / 103 ) Indian Resturants in Regent Park, Downtown Toronto:0
# ( 4 / 103 ) Indian Resturants in Lawrence Heights, Lawrence Manor, North York:0
# ( 5 / 103 ) Indian Resturants in Queen's Park , Downtown Toronto:0
# ( 6 / 103 ) Indian Resturants in Queen's Park , Queen's Park (Toronto):0
# ( 7 / 103 ) Indian Resturants in Rouge, Malvern, Scarborough, Toronto:0
# ( 8 / 103 ) Indian Resturants in Don Mills North, North York:0
# ( 9 / 103 ) Indian Resturants in Woodbine Gardens, Parkview Hill, East York:1
# ( 10 / 103 ) Indian Resturants in Garden District, Ryerson, Downtown Toronto:0
# ( 11 / 103 ) Indian Resturants in Glencairn, North York:0
# ( 12 / 103 ) Indian Resturants in Princess Gardens, Martin Grove, Islington, West Deane Park, Cloverdale, Etobicoke:0
# ( 86 / 103 ) Indian Resturants in L'Amoreaux East, Steeles East, Milliken, Ontario, Agincourt North, Scarborough, Toronto:1
# ( 87 / 103 ) Indian Resturants in Summerhill West, Forest Hill SE, South Hill, Deer Park, Rathnelly, Central Toronto:1
# ( 88 / 103 ) Indian Resturants in Railway Lands, Harbourfront West, CN Tower, South Niagara, Island airport, Bathurst Quay, King and Spadina, Downtown Toronto:0
# ( 89 / 103 ) Indian Resturants in Humber Bay Shores, New Toronto, Mimico South, Etobicoke:3
# ( 90 / 103 ) Indian Resturants in Albion Gardens, Thistletown, Humbergate, Mount Olive-Silverstone-Jamestown, Beaumond Heights, South Steeles, Silverstone, Etobicoke:5
# ( 91 / 103 ) Indian Resturants in L'Amoreaux West, Scarborough, Toronto:0
# ( 92 / 103 ) Indian Resturants in Rosedale, Downtown Toronto:0
# ( 93 / 103 ) Indian Resturants in Stn A PO Boxes 25 The Esplanade, Downtown Toronto:0
# ( 94 / 103 ) Indian Resturants in Long Branch, Alderwood, Etobicoke:0
# ( 95 / 103 ) Indian Resturants in Northwest, Etobicoke:0
# ( 96 / 103 ) Indian Resturants in Upper Rouge, Scarborough, Toronto:0
# ( 97 / 103 ) Indian Resturants in St. James Town, Cabbagetown, Downtown Toronto:1
# ( 98 / 103 ) Indian Resturants in Underground city, First Canadian Place, Downtown Toronto:0
# ( 99 / 103 ) Indian Resturants in Montgomery Road, Old Mill North, The Kingsway, Etobicoke:1
# ( 100 / 103 ) Indian Resturants in Church and Wellesley, Downtown Toronto:0
# ( 101 / 103 ) Indian Resturants in Business Reply Mail Processing Centre 969 Eastern, East Toronto:2
# ( 102 / 103 ) Indian Resturants in King's Mill Park, Kingsway Park South East, Sunnylea, Mimico, The Queensway, Old Mill, Humber Bay, Fairmont Royal York Hotel, Etobicoke:0
# ( 103 / 103 ) Indian Resturants in Kingsway Park South West, Mimico, The Queensway, Royal York South West, South of Bloor, Etobicoke:0

# %%
# lets see total number of indian restaurants in Toronto
print("Total number of Indian Restaurant in Toronto City is {}".format(indirest_toronto.shape[0]))
# Out:
# Total number of Indian Restaurant in Toronto City is 57

# %%
# lets print first five elements of Indian Restaurants
indirest_toronto.head()
# Out:
#                 Borough                     Neighborhood  \
# 0            North York                 Victoria Village
# 1             East York  Woodbine Gardens, Parkview Hill
# 2                  York               Humewood-Cedarvale
# 3          East Toronto                      The Beaches
# 4  Scarborough, Toronto                           Woburn
#
#                          ID               Name
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas
# 1  4b9bccbef964a520ae2636e3  Sultan Of Samosas
# 2  52418b0b7e48222eea81d2d2   Pukka Restaurant
# 3  4dcd7c6352b1f8915b7e7f7e       Delhi Bistro
# 4  4bd48a734e32d13a4254bf80     Govardhan Thal

# %% [markdown]
# ### Visualize the Indian Restaurants Data

# %% [markdown]
# <strong> <em>Which Borough has the maximum number of Indian Restaurants ? </em></strong>

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Restaurants for each Borough in Toronto City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Indian Restaurants', fontsize=15)
#giving a bar plot
indirest_toronto.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print("Maximum number of Indian restaurants in a single Borough is {}".format(max(indirest_toronto.groupby('Borough')['ID'].count())))
# Out:
# Maximum number of Indian restaurants in a single Borough is 15

# %% [markdown]
# <strong> <em>Which Neighborhood has the maximum number of Indian Rasoi ? </em></strong>

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Restaurants for each Neighborhood in Toronto City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No. of Indian Restaurants', fontsize=15)
#giving a bar plot
indirest_toronto.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print("Maximum number of Indian restaurants in a single Neighborhood is {}".format(max(indirest_toronto.groupby('Neighborhood')['ID'].count())))
# Out:
# Maximum number of Indian restaurants in a single Neighborhood is 5

# %% [markdown]
# ### Let's see likes, ratings and tips

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
indian_rest_stats = pd.DataFrame(columns = column_names)
count=1


for row in indirest_toronto.values.tolist():
    Borough, Neighborhood, ID, Name = row
    try:
        venue_details = get_venue_details(ID)
        print(venue_details)
        id1, name, likes, rating, tips = venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id1, name, likes, rating, tips = [0]*5
    print('(',count,'/',len(indirest_toronto),')','processed')
    indian_rest_stats = indian_rest_stats.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id1,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.4    24
# ( 1 / 57 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.4    24
# ( 2 / 57 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 3 / 57 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4dcd7c6352b1f8915b7e7f7e  Delhi Bistro      6     7.1     3
# ( 4 / 57 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.2     3
# ( 5 / 57 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     12     6.6    12
# ( 6 / 57 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     13     8.1     6
# ( 7 / 57 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     7.9    12
# ( 8 / 57 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4adb969ef964a520332921e3  Banjara Indian Cuisine    142     8.9    75
# ( 9 / 57 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     39     8.8    18
# ( 10 / 57 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4d6008f829ef236a8832a059  CANBE Foods Inc     22     8.0     8
# ( 11 / 57 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.2     3
# ( 12 / 57 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     12     6.6    12
# ( 13 / 57 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     13     8.1     6
# ( 14 / 57 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 15 / 57 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4adb969ef964a520332921e3  Banjara Indian Cuisine    142     8.9    75
# ( 16 / 57 ) processed
#                          ID                                      Name  Likes  \
# 0  4b6dbc8ef964a520fd8a2ce3  Anjappar Authentic Chettinadu Restaurant     21
#
#    Rating  Tips
# 0     8.3    10
# ( 17 / 57 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4aecbbb0f964a520bcca21e3  Mother India     45     8.3    31
# ( 18 / 57 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.4    24
# ( 19 / 57 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  5c6816acb3d8e2002c7b6383  Goa Kitchen      4     7.2     2
# ( 20 / 57 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.7    31
# ( 21 / 57 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4afc9816f964a520312422e3  Motimahal     25     7.9    13
# ( 22 / 57 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  4bac30a2f964a52018ea3ae3  Bombay Chowpatty      7     7.5     5
# ( 23 / 57 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b8f4165f964a5205f4f33e3  Rajdhani Sweets & Restaurant      3     6.6     6
# ( 24 / 57 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e17a38462e12640d86e074e
# ( 25 / 57 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     14     7.6    15
# ( 26 / 57 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.1    17
# ( 27 / 57 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5226562611d2cd49d83ef03b  Kairali      9     7.5     6
# ( 28 / 57 ) processed
#                          ID                                         Name  \
# 0  4bf96c435317a593a23a017f  Karaikudi Chettinad South Indian Restaurant
#
#    Likes  Rating  Tips
# 0     27     6.3    23
# ( 29 / 57 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     7.9    11
# ( 30 / 57 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.1    17
# ( 31 / 57 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857  Patna Kebab House      4     8.1     6
# ( 32 / 57 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5226562611d2cd49d83ef03b  Kairali      9     7.5     6
# ( 33 / 57 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  51dde446498e8598c097f3d6  The Indian Cuisine      5     6.0     2
# ( 34 / 57 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     39     8.8    18
# ( 35 / 57 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  595fb4ab178a2a1a946eec2b  Barbq Tonight      7     6.7     1
# ( 36 / 57 ) processed
#                          ID  Name  Likes  Rating  Tips
# 0  4bff0c5668c7a5932a1f4044  Zauq      9     6.4    11
# ( 37 / 57 ) processed
#                          ID                                Name  Likes  \
# 0  4d570727fb65236a7f600db4  Silver Spoon Pak-Indian Restaurant     11
#
#    Rating  Tips
# 0     7.4     6
# ( 38 / 57 ) processed
#                          ID                              Name  Likes  Rating  \
# 0  4aee2557f964a52080d221e3  Samosa King - Embassy Restaurant     36     7.7
#
#    Tips
# 0    25
# ( 39 / 57 ) processed
#                          ID                                      Name  Likes  \
# 0  4b93d4a7f964a520eb5334e3  Saravanaa Bhavan South Indian Restaurant     28
#
#    Rating  Tips
# 0     7.6    14
# ( 40 / 57 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     7.9    11
# ( 41 / 57 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.1    17
# ( 42 / 57 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     7.9    11
# ( 43 / 57 ) processed
#                          ID                                      Name  Likes  \
# 0  4b93d4a7f964a520eb5334e3  Saravanaa Bhavan South Indian Restaurant     28
#
#    Rating  Tips
# 0     7.6    14
# ( 44 / 57 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     39     8.8    18
# ( 45 / 57 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  5557eeff498ea920bf32ab39  Tich - Modern Indian Cuisine     32     8.5     8
# ( 46 / 57 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4bc10d44abf49521d773c093  Bombay on the Lake      6     7.0     9
# ( 47 / 57 ) processed
#                          ID                             Name  Likes  Rating  \
# 0  50a6bb8de4b0ec4c79616846  Maurya East Indian Roti Cuisine     10     6.2
#
#    Tips
# 0     6
# ( 48 / 57 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b8f4165f964a5205f4f33e3  Rajdhani Sweets & Restaurant      3     6.6     6
# ( 49 / 57 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4cead0ed9f776ea8bdcd6a22  Madras Dosa Hut      7     6.5     1
# ( 50 / 57 ) processed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-21ecef20c570> in <module>
#       8     Borough, Neighborhood, ID, Name = row
#       9     try:
# ---> 10         venue_details = get_venue_details(ID)
#      11         print(venue_details)
#      12         id1, name, likes, rating, tips = venue_details.values.tolist()[0]
#
# <ipython-input-12-6a45fae537ff> in get_venue_details(venue_id)
#      11     # get all the data
#      12     results = requests.get(url).json()
# ---> 13     venue_data=results['response']['venue']
#      14     venue_details=[]
#      15     try:
#
# KeyError: 'venue'

# %%
# print first five elements of indian_rest_stats
print(indian_rest_stats.columns)
# Out:
# Index(['Borough', 'Neighborhood', 'ID', 'Name', 'Likes', 'Rating', 'Tips'], dtype='object')

# %%
# print the shape of indian_rest_stats
print(indian_rest_stats)
# Out:
#                  Borough                                       Neighborhood  \
# 0             North York                                   Victoria Village
# 1              East York                    Woodbine Gardens, Parkview Hill
# 2                   York                                 Humewood-Cedarvale
# 3           East Toronto                                        The Beaches
# 4   Scarborough, Toronto                                             Woburn
# 5   Scarborough, Toronto                                             Woburn
# 6              East York                                            Leaside
# 7              East York                                            Leaside
# 8       Downtown Toronto                                           Christie
# 9       Downtown Toronto                                           Christie
# 10  Scarborough, Toronto                                          Cedarbrae
# 11  Scarborough, Toronto                                          Cedarbrae
# 12  Scarborough, Toronto                                          Cedarbrae
# 13             East York                                   Thorncliffe Park
# 14          West Toronto                       Dovercourt Village, Dufferin
# 15          West Toronto                       Dovercourt Village, Dufferin
# 16  Scarborough, Toronto                                Scarborough Village
# 17          West Toronto       Parkdale Village, Brockton, Exhibition Place
# 18  Scarborough, Toronto                    Golden Mile, Clairlea, Oakridge
# 19            North York                           York Mills, Silver Hills
# 20          East Toronto                     India Bazaar, The Beaches West
# 21          East Toronto                     India Bazaar, The Beaches West
# 22          East Toronto                     India Bazaar, The Beaches West
# 23            North York                                      Humber Summit
# 24            North York                                      Humber Summit
# 25            North York                  Bedford Park, Lawrence Manor East
# 26         York, Toronto                      The Junction North, Runnymede
# 27  Scarborough, Toronto  Dorset Park, Wexford Heights, Scarborough Town...
# 28  Scarborough, Toronto  Dorset Park, Wexford Heights, Scarborough Town...
# 29       Central Toronto                                   Davisville North
# 30          West Toronto                      The Junction South, High Park
# 31  Scarborough, Toronto                                  Wexford, Maryvale
# 32  Scarborough, Toronto                                  Wexford, Maryvale
# 33            North York                                    Willowdale West
# 34       Central Toronto                The Annex, Yorkville, North Midtown
# 35           Mississauga              Canada Post Gateway Processing Centre
# 36           Mississauga              Canada Post Gateway Processing Centre
# 37  Scarborough, Toronto                                          Agincourt
# 38  Scarborough, Toronto                                          Agincourt
# 39  Scarborough, Toronto                                          Agincourt
# 40       Central Toronto                                         Davisville
# 41          West Toronto                                 Runnymede, Swansea
# 42       Central Toronto                        Moore Park, Summerhill East
# 43  Scarborough, Toronto  L'Amoreaux East, Steeles East, Milliken, Ontar...
# 44       Central Toronto  Summerhill West, Forest Hill SE, South Hill, D...
# 45             Etobicoke       Humber Bay Shores, New Toronto, Mimico South
# 46             Etobicoke       Humber Bay Shores, New Toronto, Mimico South
# 47             Etobicoke       Humber Bay Shores, New Toronto, Mimico South
# 48             Etobicoke  Albion Gardens, Thistletown, Humbergate, Mount...
# 49             Etobicoke  Albion Gardens, Thistletown, Humbergate, Mount...
#
#                           ID                                         Name  \
# 0   4b9bccbef964a520ae2636e3                            Sultan Of Samosas
# 1   4b9bccbef964a520ae2636e3                            Sultan Of Samosas
# 2   52418b0b7e48222eea81d2d2                             Pukka Restaurant
# 3   4dcd7c6352b1f8915b7e7f7e                                 Delhi Bistro
# 4   4bd48a734e32d13a4254bf80                               Govardhan Thal
# 5   4c77fc87bd346dcb8c90f0ef                                La Sani Grill
# 6   4daf08e66e81e2dffdd4fe40                   Iqbal Kebab & Sweet Centre
# 7   4b75c28af964a520ba222ee3                                    Kamasutra
# 8   4adb969ef964a520332921e3                       Banjara Indian Cuisine
# 9   4c62c59ce1621b8dd0332453                        Roti Cuisine of India
# 10  4d6008f829ef236a8832a059                              CANBE Foods Inc
# 11  4bd48a734e32d13a4254bf80                               Govardhan Thal
# 12  4c77fc87bd346dcb8c90f0ef                                La Sani Grill
# 13  4daf08e66e81e2dffdd4fe40                   Iqbal Kebab & Sweet Centre
# 14  52418b0b7e48222eea81d2d2                             Pukka Restaurant
# 15  4adb969ef964a520332921e3                       Banjara Indian Cuisine
# 16  4b6dbc8ef964a520fd8a2ce3     Anjappar Authentic Chettinadu Restaurant
# 17  4aecbbb0f964a520bcca21e3                                 Mother India
# 18  4b9bccbef964a520ae2636e3                            Sultan Of Samosas
# 19  5c6816acb3d8e2002c7b6383                                  Goa Kitchen
# 20  4ae0c7a8f964a520638221e3                                 Udupi Palace
# 21  4afc9816f964a520312422e3                                    Motimahal
# 22  4bac30a2f964a52018ea3ae3                             Bombay Chowpatty
# 23  4b8f4165f964a5205f4f33e3                 Rajdhani Sweets & Restaurant
# 24                         0                                            0
# 25  4d796616542ab1f75eb87c41                           The Copper Chimney
# 26  4b511f6ff964a520994327e3                                  Curry Twist
# 27  5226562611d2cd49d83ef03b                                      Kairali
# 28  4bf96c435317a593a23a017f  Karaikudi Chettinad South Indian Restaurant
# 29  5169d445e4b07de190b5c3d6                       Marigold Indian Bistro
# 30  4b511f6ff964a520994327e3                                  Curry Twist
# 31  4c27cddd9fb5d13a8cab9857                            Patna Kebab House
# 32  5226562611d2cd49d83ef03b                                      Kairali
# 33  51dde446498e8598c097f3d6                           The Indian Cuisine
# 34  4c62c59ce1621b8dd0332453                        Roti Cuisine of India
# 35  595fb4ab178a2a1a946eec2b                                Barbq Tonight
# 36  4bff0c5668c7a5932a1f4044                                         Zauq
# 37  4d570727fb65236a7f600db4           Silver Spoon Pak-Indian Restaurant
# 38  4aee2557f964a52080d221e3             Samosa King - Embassy Restaurant
# 39  4b93d4a7f964a520eb5334e3     Saravanaa Bhavan South Indian Restaurant
# 40  5169d445e4b07de190b5c3d6                       Marigold Indian Bistro
# 41  4b511f6ff964a520994327e3                                  Curry Twist
# 42  5169d445e4b07de190b5c3d6                       Marigold Indian Bistro
# 43  4b93d4a7f964a520eb5334e3     Saravanaa Bhavan South Indian Restaurant
# 44  4c62c59ce1621b8dd0332453                        Roti Cuisine of India
# 45  5557eeff498ea920bf32ab39                 Tich - Modern Indian Cuisine
# 46  4bc10d44abf49521d773c093                           Bombay on the Lake
# 47  50a6bb8de4b0ec4c79616846              Maurya East Indian Roti Cuisine
# 48  4b8f4165f964a5205f4f33e3                 Rajdhani Sweets & Restaurant
# 49  4cead0ed9f776ea8bdcd6a22                              Madras Dosa Hut
#
#    Likes  Rating Tips
# 0     29     8.4   24
# 1     29     8.4   24
# 2     41     9.0   26
# 3      6     7.1    3
# 4      7     7.2    3
# 5     12     6.6   12
# 6     13     8.1    6
# 7     18     7.9   12
# 8    142     8.9   75
# 9     39     8.8   18
# 10    22     8.0    8
# 11     7     7.2    3
# 12    12     6.6   12
# 13    13     8.1    6
# 14    41     9.0   26
# 15   142     8.9   75
# 16    21     8.3   10
# 17    45     8.3   31
# 18    29     8.4   24
# 19     4     7.2    2
# 20    79     8.7   31
# 21    25     7.9   13
# 22     7     7.5    5
# 23     3     6.6    6
# 24     0     0.0    0
# 25    14     7.6   15
# 26    20     8.1   17
# 27     9     7.5    6
# 28    27     6.3   23
# 29    11     7.9   11
# 30    20     8.1   17
# 31     4     8.1    6
# 32     9     7.5    6
# 33     5     6.0    2
# 34    39     8.8   18
# 35     7     6.7    1
# 36     9     6.4   11
# 37    11     7.4    6
# 38    36     7.7   25
# 39    28     7.6   14
# 40    11     7.9   11
# 41    20     8.1   17
# 42    11     7.9   11
# 43    28     7.6   14
# 44    39     8.8   18
# 45    32     8.5    8
# 46     6     7.0    9
# 47    10     6.2    6
# 48     3     6.6    6
# 49     7     6.5    1

# %% [markdown]
# ### Let's seet the Neighbourhood with maximum average rating of Indian Restaurant

# %%
toronto_neighborhood_stats = indian_rest_stats.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
toronto_neighborhood_stats.columns = ['Neighborhood','Average Rating']
toronto_neighborhood_stats.sort_values(by = 'Average Rating', ascending = False, inplace = True)

toronto_neighborhood_stats.head()
# Out:
#                                          Neighborhood  Average Rating
# 13                                 Humewood-Cedarvale            9.00
# 9                        Dovercourt Village, Dufferin            8.95
# 5                                            Christie            8.85
# 21  Summerhill West, Forest Hill SE, South Hill, D...            8.80
# 22                The Annex, Yorkville, North Midtown            8.80

# %%
# print the neighborhood with maximum rating
print("Neighborhood : {}, Average Rating : {}".format(toronto_neighborhood_stats.iloc[0][0] ,toronto_neighborhood_stats.iloc[0][1]))
# Out:
# Neighborhood : Humewood-Cedarvale, Average Rating : 9.0

# %% [markdown]
# <strong>Lets merge this data with original data</strong>

# %%
toronto_neighborhood_stats = pd.merge(toronto_neighborhood_stats,toronto_data, on='Neighborhood')
toronto_neighborhood_stats.reset_index()
toronto_neighborhood_stats
# Out:
#                                          Neighborhood  Average Rating  \
# 0                                  Humewood-Cedarvale        9.000000
# 1                        Dovercourt Village, Dufferin        8.950000
# 2                                            Christie        8.850000
# 3   Summerhill West, Forest Hill SE, South Hill, D...        8.800000
# 4                 The Annex, Yorkville, North Midtown        8.800000
# 5                     Woodbine Gardens, Parkview Hill        8.400000
# 6                                    Victoria Village        8.400000
# 7                     Golden Mile, Clairlea, Oakridge        8.400000
# 8                                 Scarborough Village        8.300000
# 9        Parkdale Village, Brockton, Exhibition Place        8.300000
# 10                                 Runnymede, Swansea        8.100000
# 11                      The Junction North, Runnymede        8.100000
# 12                                   Thorncliffe Park        8.100000
# 13                      The Junction South, High Park        8.100000
# 14                     India Bazaar, The Beaches West        8.033333
# 15                                            Leaside        8.000000
# 16                                   Davisville North        7.900000
# 17                        Moore Park, Summerhill East        7.900000
# 18                                         Davisville        7.900000
# 19                                  Wexford, Maryvale        7.800000
# 20  L'Amoreaux East, Steeles East, Milliken, Ontar...        7.600000
# 21                  Bedford Park, Lawrence Manor East        7.600000
# 22                                          Agincourt        7.566667
# 23                                          Cedarbrae        7.266667
# 24       Humber Bay Shores, New Toronto, Mimico South        7.233333
# 25                           York Mills, Silver Hills        7.200000
# 26                                        The Beaches        7.100000
# 27  Dorset Park, Wexford Heights, Scarborough Town...        6.900000
# 28                                             Woburn        6.900000
# 29              Canada Post Gateway Processing Centre        6.550000
# 30  Albion Gardens, Thistletown, Humbergate, Mount...        6.550000
# 31                                    Willowdale West        6.000000
# 32                                      Humber Summit        3.300000
#
#                  Borough   Latitude  Longitude
# 0                   York  43.693781 -79.428191
# 1           West Toronto  43.669005 -79.442259
# 2       Downtown Toronto  43.669542 -79.422564
# 3        Central Toronto  43.686412 -79.400049
# 4        Central Toronto  43.672710 -79.405678
# 5              East York  43.706397 -79.309937
# 6             North York  43.725882 -79.315572
# 7   Scarborough, Toronto  43.711112 -79.284577
# 8   Scarborough, Toronto  43.744734 -79.239476
# 9           West Toronto  43.636847 -79.428191
# 10          West Toronto  43.651571 -79.484450
# 11         York, Toronto  43.673185 -79.487262
# 12             East York  43.705369 -79.349372
# 13          West Toronto  43.661608 -79.464763
# 14          East Toronto  43.668999 -79.315572
# 15             East York  43.709060 -79.363452
# 16       Central Toronto  43.712751 -79.390197
# 17       Central Toronto  43.689574 -79.383160
# 18       Central Toronto  43.704324 -79.388790
# 19  Scarborough, Toronto  43.750072 -79.295849
# 20  Scarborough, Toronto  43.815252 -79.284577
# 21            North York  43.733283 -79.419750
# 22  Scarborough, Toronto  43.794200 -79.262029
# 23  Scarborough, Toronto  43.773136 -79.239476
# 24             Etobicoke  43.605647 -79.501321
# 25            North York  43.757490 -79.374714
# 26          East Toronto  43.676357 -79.293031
# 27  Scarborough, Toronto  43.757410 -79.273304
# 28  Scarborough, Toronto  43.770992 -79.216917
# 29           Mississauga  43.636966 -79.615819
# 30             Etobicoke  43.739416 -79.588437
# 31            North York  43.782736 -79.442259
# 32            North York  43.756303 -79.565963

# %% [markdown]
# ### Let's use folium for visualization using map

# %%
toronto_map = folium.Map(location = [43.653963, -79.387207 ], zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in toronto_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <strong>Create labels also</strong>

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location = [43.653963, -79.387207 ], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_neighborhood_stats['Latitude'], toronto_neighborhood_stats['Longitude'], toronto_neighborhood_stats['Borough'], toronto_neighborhood_stats['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Save the map

# %%
map_toronto.save('Neighbourhood_rating.html')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# <ul>
#     <li>Humewood-Cedarvale,Dufferin, Dovercourt Village	are some of the best neighborhoods for Indian Restaurants. </li>
#     <li>York (borough) is the best place if you prefer Indian foods.</li>
# </ul>

# %% [markdown]
# ## Limitations

# %% [markdown]
# <ul><li>The accuracy is dependent on the data provided by FourSquare and the ranking is dependent on the user ratings.</li></ul>
